# %%
# %.\venv_training\Scripts\Activate
# !python model_training\synthesize.py --model_dir "..\Models\voicelk_vits_pathnirwana-September-03-2026_06+35PM-de782c1" --text "කුඹුර ගොවියාට වී ලබා ගැනීමට උපකාරී වීම් වශයෙන් පිහිට වන්නකි." --speaker_id 0 --out test_output.wav
